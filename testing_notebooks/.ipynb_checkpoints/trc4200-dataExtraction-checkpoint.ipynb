# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [20, 16]

# %%
# !{sys.executable} -m pip install PyAthena
# Out:
# ...
#     100% |████████████████████████████████| 61kB 25.6MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 829kB 24.4MB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for future ... done
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built future
# ...
# You are using pip version 10.0.1, however version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from pyathena import connect

# %%
conn = connect(s3_staging_dir ='s3://trc4200-database/queries/', region_name='us-east-1')

# %%
# @note the fcu dataset extracted is only for the north
fcu_data = pd.read_sql("SELECT * FROM ltb_database_athena.fcudataTRC4200;",conn)
fcu_data = fcu_data.drop([0])

# %%
# @note the wifi dataset only comprises instances from February
wifi_data = pd.read_sql("SELECT * FROM ltb_database_athena.wifiTRCdata;",conn)
wifi_data = wifi_data.drop([0])

# %%
# Get an overview of the dataframe object
print(fcu_data.describe())
print(wifi_data.describe())
# Out:
#        fcu-00-01 satmp extended trend log  fcu-00-01 zntmp extended trend log  \
# count                        50496.000000                        50496.000000
# mean                            17.140596                           21.373818
# std                              7.466225                            3.145971
# min                              0.000000                            6.710000
# 25%                             12.000000                           21.000000
# 50%                             21.540000                           22.160000
# 75%                             22.910000                           23.110000
# max                             25.060000                           25.790000
#
#        fcu-00-02 satmp extended trend log  fcu-00-02 zntmp extended trend log  \
# count                        50496.000000                        50496.000000
# mean                            22.704348                           20.730167
# ...

# %%
fcu_data
# Out:
#            timestamp  fcu-00-01 satmp extended trend log  \
# 1      16/3/20 14:20                               23.58
# 2      16/3/20 14:15                               23.59
# 3      16/3/20 14:10                               23.57
# 4      16/3/20 14:05                               23.62
# 5      16/3/20 14:00                               23.59
# 6      16/3/20 13:55                               23.59
# 7      16/3/20 13:50                               23.51
# 8      16/3/20 13:45                               23.41
# 9      16/3/20 13:40                               23.34
# 10     16/3/20 13:35                               23.20
# 11     16/3/20 13:30                               23.18
# 12     16/3/20 13:25                               23.12
# 13     16/3/20 13:20                               23.03
# 14     16/3/20 13:15                               22.97
# 15     16/3/20 13:10                               22.84
# ...

# %%
## Extract temperature of the FCU for northern
# Reference syntax for sanity checks
# sample_data = fcu_data["fcu-00-01 satmp extended trend log"]
# sample_data = sample_data[:1]

# Set up hyperparameters for the analysis
fcu_heat_threshold = 21.5
average_people = 0.0
heading_list = ["fcu-00-01 satmp extended trend log",
                "fcu-00-01 zntmp extended trend log",
                "fcu-00-02 satmp extended trend log",
                "fcu-00-02 zntmp extended trend log",
                "fcu-00-04 satmp extended trend log",
                "fcu-00-04 zntmp extended trend log",
                "fcu-00-06 satmp extended trend log",
                "fcu-00-06 zntmp extended trend log",
                "fcu-00-07 satmp extended trend log",
                "fcu-00-07 zntmp extended trend log",
                "fcu-00-08 satmp extended trend log",
                "fcu-00-08 zntmp extended trend log",
                "fcu-00-09 satmp extended trend log",
                "fcu-00-09 zntmp extended trend log"
               ]
for i in range(0, len(heading_list)):
    fcu_data.plot(x = "timestamp", y = heading_list[i])
    plt.savefig('Plot of ' + heading_list[i] + '.png')
